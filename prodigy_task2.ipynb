# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
pclass_names = {
    1:"First class",
    2:"Second class",
    3:"Third class"
}
df['pclass name']=df['pclass'].map(pclass_names)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  pclass name
# 0    man        True  NaN  Southampton    no  False  Third class
# 1  woman       False    C    Cherbourg   yes  False  First class
# 2  woman       False  NaN  Southampton   yes   True  Third class
# 3  woman       False    C  Southampton   yes  False  First class
# 4    man        True  NaN  Southampton    no   True  Third class

# %%
df['Family']=df['sibsp']+df["parch"]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  pclass name  Family
# 0    man        True  NaN  Southampton    no  False  Third class       1
# 1  woman       False    C    Cherbourg   yes  False  First class       1
# 2  woman       False  NaN  Southampton   yes   True  Third class       0
# 3  woman       False    C  Southampton   yes  False  First class       1
# 4    man        True  NaN  Southampton    no   True  Third class       0

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292
# Family    891.0   0.904602   1.613459  0.00   0.0000   0.0000   1.0   10.0000

# %%
cont_val = df[['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'who']]
sns.set_style('darkgrid')
sns.set_palette('pastel')
sns.heatmap(cont_val.corr(),cmap='Greens',annot=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\1913373545.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cont_val.corr(),cmap='Greens',annot=True)
# <Axes: >

# %%
sns.countplot(data=df,x="pclass name" , hue='sex')
# Out:
# <Axes: xlabel='pclass name', ylabel='count'>

# %%
sns.set_style('white')
sns.displot(data=df,x="age",bins=15,palette='dark',hue='survived',hue_order=[1,0])

# %%
survived=df[df["survived"]==1]
ax=sns.countplot(data=df,x="pclass name",hue='sex',palette='dark')
ax=sns.countplot(data=survived,x="pclass name",hue='sex')
plt.legend(labels=['Male','Female','survived Male','survived Female'])
